# %%
# 題目 : 將資料夾中 boston.csv 讀進來，並用圖表分析欄位。
# 1. 畫出箱型圖，並判斷哪個欄位的中位數在 300~400 之間？
import pandas as pd
import numpy as np
boston_data = pd.read_csv('boston.csv')
df = pd.DataFrame(boston_data)
print('\n箱型圖：', df.boxplot())
#答案: TAX 與 B 欄位的中位數在 300~400 之間
# Out:
# 箱型圖： AxesSubplot(0.125,0.125;0.775x0.755)

# %%
# 2. 畫出散佈圖 x='NOX', y='DIS' ，並說明這兩欄位有什麼關係？
#print('讀入 boston.csv 前五筆資料如下：\n', boston_data.head())
print('\n資料(列,欄位)：',boston_data.shape)
df = pd.DataFrame(np.random.rand(505, 2), columns=["NOX","DIS"])
sc = df.plot.scatter(x='NOX', y='DIS')
print('\nNOX 與 DIS 散佈圖：',sc)
#答案: 從 NOX 與 DIS 散佈圖看來，兩者並沒有任何的關係
# Out:
# 資料(列,欄位)： (505, 14)
#
# NOX 與 DIS 散佈圖： AxesSubplot(0.125,0.125;0.775x0.755)
